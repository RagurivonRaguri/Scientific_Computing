# %%
import pandas as pd

# %%
data=pd.read_csv('sample_data.csv.xls')

# %%
data
# Out:
#    temperature  humidity   category
# 0           22        55    Science
# 1           25        60       Math
# 2           27        65    Physics
# 3           30        70    Biology
# 4           35        75  Chemistry

# %%
print(data)
# Out:
#    temperature  humidity   category
# 0           22        55    Science
# 1           25        60       Math
# 2           27        65    Physics
# 3           30        70    Biology
# 4           35        75  Chemistry

# %%
dataW=pd.read_csv('iris.csv')
dataW
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.describe()
# Out:
#        temperature   humidity
# count     5.000000   5.000000
# mean     27.800000  65.000000
# std       4.969909   7.905694
# min      22.000000  55.000000
# 25%      25.000000  60.000000
# 50%      27.000000  65.000000
# 75%      30.000000  70.000000
# max      35.000000  75.000000

# %%
data.describe(include='all')
# Out:
#         temperature   humidity category
# count      5.000000   5.000000        5
# unique          NaN        NaN        5
# top             NaN        NaN  Science
# freq            NaN        NaN        1
# mean      27.800000  65.000000      NaN
# std        4.969909   7.905694      NaN
# min       22.000000  55.000000      NaN
# 25%       25.000000  60.000000      NaN
# 50%       27.000000  65.000000      NaN
# 75%       30.000000  70.000000      NaN
# max       35.000000  75.000000      NaN

# %%
data.head(2)
# Out:
#    temperature  humidity category
# 0           22        55  Science
# 1           25        60     Math

# %%
data.sample()
# Out:
#    temperature  humidity category
# 2           27        65  Physics

# %%
data.cov()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 data.cov()
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11204, in DataFrame.cov(self, min_periods, ddof, numeric_only)
#   11202 cols = data.columns
#   11203 idx = cols.copy()
# > 11204 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11206 if notna(mat).all():
#   11207     if min_periods is not None and min_periods > len(mat):
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
data.loc[data['category'] == 'Science', ['temperature', 'humidity']]
# Out:
#    temperature  humidity
# 0           22        55

# %%
data[data['category'] == 'Science'][['temperature', 'humidity']]
# Out:
#    temperature  humidity
# 0           22        55

# %%
data[data['temperature']>30]
# Out:
#    temperature  humidity   category
# 4           35        75  Chemistry

# %%
import matplotlib.pyplot as plt

# %%
data.plot()
plt.show()

# %%
data['temperature'].hist(bins=5, color='green')
plt.title('Histogram of temperature')
plt.ylabel('Frequency')
plt.xlabel('Temperature')
plt.show()

# %% [markdown]
# ## Cleaning and Preprocessing

# %%
data.isnull().sum()
# Out:
# temperature    0
# humidity       0
# category       0
# dtype: int64

# %%
datanew = pd.read_csv('./sample_data.csv.xls')

# %%
datanew
# Out:
#    temperature  humidity   category
# 0           22      55.0    Science
# 1           25       NaN       Math
# 2           27      65.0    Physics
# 3           30      70.0    Biology
# 4           35      75.0  Chemistry

# %%
datanew.isnull().sum()
# Out:
# temperature    0
# humidity       1
# category       0
# dtype: int64

# %%
datanew.fillna(10, inplace=True)

# %% [markdown]
# ## Handling Outliers

# %%
q1 = data['temperature'].quantile(0.25)
q2 = data['temperature'].quantile(0.75)
IQR = q2 - q1
no_outliers = data[(data['temperature'] > q1 - 1.5 * IQR) & (data['temperature'] < q2 + 1.5 * IQR)]

# %%
no_outliers
# Out:
#    temperature  humidity   category
# 0           22        55    Science
# 1           25        60       Math
# 2           27        65    Physics
# 3           30        70    Biology
# 4           35        75  Chemistry

# %% [markdown]
# ## Normalizing and Transforming Data
#
# standardizing

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
scaled_data = scaler.fit_transform(data[['temperature', 'humidity']])

# %%
scaled_data
# Out:
# array([[-1.30477168, -1.41421356],
#        [-0.62988978, -0.70710678],
#        [-0.17996851,  0.        ],
#        [ 0.4949134 ,  0.70710678],
#        [ 1.61971657,  1.41421356]])

# %% [markdown]
# ## - Get data, load it and inspect it
# - make sure the data downloaded has missing values
# - write analysis and comments on work being done
#
# ## - Handle missing values and outliers
#
# ## - Compute key statistics about data
# - mean, std, count
#
# ## - Generate Visualizations
# - histogram
# - scatterplot
# - correlation heatmap
